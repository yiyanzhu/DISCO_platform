# %%
# 绘图脚本自带功能
from draw_step import step_graph, NO2RR1
step_graph('example.txt', NO2RR1, '*', figsize=(8, 5.5), ylim=(-6, 1), dpi=300, U=0, pH=1)
# Out:
# c:\Users\hp\Desktop\platform\utils\draw_step.py:41: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv(file_path, delim_whitespace=True) # sep='\s+'
# 决速步: Step 4: ['NO', 'h']→['HNO']
# 势垒值: 0.63 eV
